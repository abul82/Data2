# %%
pip freeze
# Out:
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.2
# asn1crypto==0.24.0
# astroid==2.2.5
# astropy==3.1.2
# atomicwrites==1.3.0
# attrs==19.1.0
# Babel==2.6.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.7.1
# bitarray==0.8.3
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.0.4
# boto==2.49.0
# Bottleneck==1.2.1
# certifi==2019.3.9
# cffi==1.12.2
# chardet==3.0.4
# Click==7.0
# cloudpickle==0.8.0
# clyent==1.2.2
# colorama==0.4.1
# comtypes==1.1.7
# conda==4.6.11
# conda-build==3.17.8
# conda-verify==3.1.1
# contextlib2==0.5.5
# cryptography==2.6.1
# cycler==0.10.0
# Cython==0.29.6
# cytoolz==0.9.0.1
# dask==1.1.4
# decorator==4.4.0
# defusedxml==0.5.0
# distributed==1.26.0
# docutils==0.14
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# filelock==3.0.10
# Flask==1.0.2
# future==0.17.1
# gevent==1.4.0
# glob2==0.6
# greenlet==0.4.15
# h5py==2.9.0
# heapdict==1.0.0
# html5lib==1.0.1
# idna==2.8
# imageio==2.5.0
# imagesize==1.1.0
# importlib-metadata==0.0.0
# ipykernel==5.1.0
# ipython==7.4.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# isort==4.3.16
# itsdangerous==1.1.0
# jdcal==1.4
# jedi==0.13.3
# Jinja2==2.10
# jsonschema==3.0.1
# jupyter==1.0.0
# jupyter-client==5.2.4
# jupyter-console==6.0.0
# jupyter-core==4.4.0
# jupyterlab==0.35.4
# jupyterlab-server==0.2.0
# keyring==18.0.0
# kiwisolver==1.0.1
# lazy-object-proxy==1.3.1
# libarchive-c==2.8
# llvmlite==0.28.0
# locket==0.2.0
# lxml==4.3.2
# MarkupSafe==1.1.1
# matplotlib==3.0.3
# mccabe==0.6.1
# menuinst==1.4.16
# mistune==0.8.4
# mkl-fft==1.0.10
# mkl-random==1.0.2
# more-itertools==6.0.0
# mpmath==1.1.0
# msgpack==0.6.1
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.4.1
# nbformat==4.4.0
# networkx==2.2
# nltk==3.4
# nose==1.3.7
# notebook==5.7.8
# numba==0.43.1
# numexpr==2.6.9
# numpy==1.16.2
# numpydoc==0.8.0
# oauthlib==3.0.1
# olefile==0.46
# openpyxl==2.6.1
# packaging==19.0
# pandas==0.24.2
# pandocfilters==1.4.2
# parso==0.3.4
# partd==0.3.10
# path.py==11.5.0
# pathlib2==2.3.3
# patsy==0.5.1
# pep8==1.7.1
# pickleshare==0.7.5
# Pillow==5.4.1
# pkginfo==1.5.0.1
# pluggy==0.9.0
# ply==3.11
# prometheus-client==0.6.0
# prompt-toolkit==2.0.9
# psutil==5.6.1
# py==1.8.0
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.2
# pyflakes==2.1.1
# Pygments==2.3.1
# pylint==2.3.1
# pyodbc==4.0.26
# pyOpenSSL==19.0.0
# pyparsing==2.3.1
# pyreadline==2.1
# pyrsistent==0.14.11
# PySocks==1.6.8
# pytest==4.3.1
# pytest-arraydiff==0.3
# pytest-astropy==0.5.0
# pytest-doctestplus==0.3.0
# pytest-openfiles==0.3.2
# pytest-remotedata==0.3.1
# python-dateutil==2.8.0
# pytz==2018.9
# PyWavelets==1.0.2
# pywin32==223
# pywinpty==0.5.5
# PyYAML==5.1
# pyzmq==18.0.0
# QtAwesome==0.5.7
# qtconsole==4.4.3
# QtPy==1.7.0
# requests==2.21.0
# requests-oauthlib==1.2.0
# rope==0.12.0
# ruamel-yaml==0.15.46
# scikit-image==0.14.2
# scikit-learn==0.20.3
# scipy==1.2.1
# seaborn==0.9.0
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.12.0
# snowballstemmer==1.2.1
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# soupsieve==1.8
# Sphinx==1.8.5
# sphinxcontrib-websupport==1.1.0
# spyder==3.3.3
# spyder-kernels==0.4.2
# SQLAlchemy==1.3.1
# statsmodels==0.9.0
# sympy==1.3
# tables==3.5.1
# tblib==1.3.2
# terminado==0.8.1
# testpath==0.4.2
# toolz==0.9.0
# tornado==6.0.2
# tqdm==4.31.1
# traitlets==4.3.2
# tweepy==3.7.0
# unicodecsv==0.14.1
# urllib3==1.24.1
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# widgetsnbextension==3.4.2
# win-inet-pton==1.1.0
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt==1.11.1
# xlrd==1.2.0
# XlsxWriter==1.1.5
# xlwings==0.15.4
# xlwt==1.3.0
# zict==0.1.4
# zipp==0.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import tweepy 
import pandas as pd

# %%
consumer_key = "cfhtDBkVFfC4VyXtlkSUOpLe8"
consumer_secret = "eX7BAGWbnnptAcDN7YqXUb1uoQ8TLO7Zdsx48CIxt1FBgQ9Hiv"
access_key = "1138316071910297600-1cwVGr1m9Me0IYos4ONGpbIF0Dcol2"
access_secret = "udR3MwXueqWz50FoEIfshXH4WbNsfZ4CJWQFOaWxk8ksu"

# %%
def get_tweets(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
        # Access to user's access key and access secret 
        auth.set_access_token(access_key, access_secret) 
  
        # Calling api 
        api = tweepy.API(auth) 
  
        # 200 tweets to be extracted 
        number_of_tweets=2000
        tweets = api.user_timeline(screen_name=username) 
  
        # Empty Array 
        tmp=[]  
  
        # create array of tweet information: username,  
        # tweet id, date/time, text 
        import csv
        csvfile=open('tweets.csv','a')
        csvwriter = csv.writer(csvfile)
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
  
            # Appending tweets to the empty array tmp 
            tmp.append(j)  
            csvwriter.writerow([j.encode('utf-8')])
  
        # Printing the tweets 
        print(tmp) 
        
       
        csvfile.close()
  
  
# Driver code 
if __name__ == '__main__': 
  
    # Here goes the twitter handle for the user 
    # whose tweets are to be extracted. 
    get_tweets("@MKBHD")
# Out:
# ["@samsheffer @Casey @piamuehlenbeck If you're buying, yes. 100%. If you're leasing, not necessarily.", 'Gamers: We like high end specs\n\nAsus: Say no more fam\n\nAsus ROG Phone II\n6.6" 120Hz OLED\nSnapdragon 855+\n12GB of RA… https://t.co/WVsEIKgrjp', "RT @empireultimate: EMPIRE WINS!!! We're going to championship weekend!!!", "@austinnotduncan Can't forget occasional hurricanes and tropical storms, we really run the full gamut here 😅", "@stshank @wunderground First one. I'm in traffic on black asphalt. It's literally hotter out here in these streets 😅", "SHEESH it's hot out here in these streets. https://t.co/xFPG978wDQ", 'RT @MKBHD: NEW VIDEO - The Last (and First) Folding Phone! https://t.co/jwDCcdHTQd - RT! https://t.co/2cEVaNIVzz', '@YagnaPatel9 So good', '@Brandon_Y_Lee Yes', "Ok I'm not even a cat person but honestly this is my favorite Instagram account right now\n\nhttps://t.co/fv47zRC8zk https://t.co/SzW3uiATCA", '"Being first doesn\'t matter if it sucks" - Inspired by the Royole Flexpai', 'TWEETS BUT WITH EDITING', "@KTasterisk I can't disagree", '@abhishek1point0 This is all fantastic logical speculation, but actually using the thing changes your mind real quick', 'RT @zivbuzaglo: Bro......\n@MKBHD https://t.co/QbynjD4q2H', '@superscientific Fire', '@SalahEl_Deen 😅', 'NEW VIDEO - The Last (and First) Folding Phone! https://t.co/jwDCcdHTQd - RT! https://t.co/2cEVaNIVzz', '🔥 Uploading… 🔥', "AirPower Award 2019 goes to: Bixby speaker 🏆\n\n345 days since Samsung Galaxy Home was announced. Hasn't shipped. But who's counting?"]

# %%
import nltk
import pandas as pd
dataset = pd.read_csv('tweets.csv','r',error_bad_lines=False)

# %%
pat=r'''#\w+'''
tokenizer = nltk.regexp_tokenize(str(dataset),pat)
tokenizer
# Out:
# ['#CWC19Finals', '#basushanke']

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
tokenizer=list(dict.fromkeys(tokenizer))
tokenizer
# Out:
# ['#CWC19Finals', '#basushanke']

# %%
stemtoken=[]
for token in tokenizer:
    print(ps.stem(token))
    stemtoken.append(ps.stem(token))
# Out:
# #cwc19final
# #basushank

# %%
from nltk import ngrams
n=3
ngrm=[]
res = ngrams(str(dataset).split(),n) 
for s in res:
    ngrm.append(s)
ngrm
# Out:
# [("b'Also", 'exquisite', 'display'),
#  ('exquisite', 'display', 'of'),
#  ('display', 'of', 'spo'),
#  ('of', 'spo', '\\'),
#  ('spo', '\\', '0'),
#  ('\\', '0', "b'G"),
#  ('0', "b'G", '1'),
#  ("b'G", '1', "b'Thank"),
#  ('1', "b'Thank", 'you'),
#  ("b'Thank", 'you', 'Patrick'),
#  ('you', 'Patrick', 'and'),
#  ('Patrick', 'and', 'Basu'),
#  ('and', 'Basu', 'for'),
#  ('Basu', 'for', 'the'),
#  ('for', 'the', 'amazing'),
#  ('the', 'amazing', 'w...'),
#  ('amazing', 'w...', '2'),
#  ('w...', '2', "b'Fi"),
#  ('2', "b'Fi", '3'),
#  ("b'Fi", '3', 'b"Happy'),
#  ('3', 'b"Happy', 'birthday'),
#  ('b"Happy', 'birthday', 'mahi'),
#  ('birthday', 'mahi', 'bhai'),
#  ('mahi', 'bhai', '@msdhoni.'),
#  ('bhai', '@msdhoni.', 'Very'),
#  ('@msdhoni.', 'Very', 'few'),
#  ('Very', 'few', '...'),
#  ('few', '...', '4'),
#  ('...', '4', "b'On"),
#  ('4', "b'On", 'to'),
#  ("b'On", 'to', 'the'),
#  ('to', 'the', 'semis'),
#  ('the', 'semis', 'now!'),
#  ('semis', 'now!', '\\xf0\\x9f\\x87\\xae\\xf0\\x9...'),
#  ('now!', '\\xf0\\x9f\\x87\\xae\\xf0\\x9...', '5'),
#  ('\\xf0\\x9f\\x87\\xae\\xf0\\x9...', '5', "b'Smiles"),
#  ('5', "b'Smiles", 'all'),
#  ("b'Smiles", 'all', 'a'),
#  ('all', 'a', '6'),
#  ('a', '6', "b'Was"),
#  ('6', "b'Was", 'fun'),
#  ("b'Was", 'fun', 'catching'),
#  ('fun', 'catching', 'up'),
#  ('catching', 'up', 'with'),
#  ('up', 'with', 'you'),
#  ('with', 'you', 'Ha'),
#  ('you', 'Ha', '7'),
#  ('Ha', '7', "b'M"),
#  ('7', "b'M", '8'),
#  ("b'M", '8', 'b"Wish'),
#  ('8', 'b"Wish', 'you'),
#  ('b"Wish', 'you', 'a'),
#  ('you', 'a', 'very'),
#  ('a', 'very', 'Happy'),
#  ('very', 'Happy', "B'day"),
#  ('Happy', "B'day", 'Bhajju'),
#  ("B'day", 'Bhajju', 'Pa.'),
#  ('Bhajju', 'Pa.', '\\xf0\\...'),
#  ('Pa.', '\\xf0\\...', '9'),
#  ('\\xf0\\...', '9', 'b"Wish'),
#  ('9', 'b"Wish', 'you'),
#  ('b"Wish', 'you', 'the'),
#  ('you', 'the', 'best'),
#  ('the', 'best', 'going'),
#  ('best', 'going', 'forward'),
#  ('going', 'forward', 'Ambati.'),
#  ('forward', 'Ambati.', "You'..."),
#  ('Ambati.', "You'...", '10'),
#  ("You'...", '10', 'b"Also'),
#  ('10', 'b"Also', 'would'),
#  ('b"Also', 'would', 'like'),
#  ('would', 'like', 'to'),
#  ('like', 'to', 'thank'),
#  ('to', 'thank', 'all'),
#  ('thank', 'all', 'our'),
#  ('all', 'our', 'fans'),
#  ('our', 'fans', 'for'),
#  ('fans', 'for', 'al...'),
#  ('for', 'al...', '11'),
#  ('al...', '11', "b'What"),
#  ('11', "b'What", 'a'),
#  ("b'What", 'a', 'unit.'),
#  ('a', 'unit.', 'We'),
#  ('unit.', 'We', 'ma'),
#  ('We', 'ma', '12'),
#  ('ma', '12', "b'\\xf0\\x9f\\x91\\x95\\xf0\\x9f\\x91\\x8c\\xf0\\x9f\\x91..."),
#  ('12', "b'\\xf0\\x9f\\x91\\x95\\xf0\\x9f\\x91\\x8c\\xf0\\x9f\\x91...", '13'),
#  ("b'\\xf0\\x9f\\x91\\x95\\xf0\\x9f\\x91\\x8c\\xf0\\x9f\\x91...",
#   '13',
#   "b'Belief"),
#  ('13', "b'Belief", 'is'),
#  ("b'Belief", 'is', 'a'),
#  ('is', 'a', 'beautiful'),
#  ('a', 'beautiful', 'gift.'),
#  ('beautiful', 'gift.', 'We'),
#  ('gift.', 'We', 'must'),
#  ('We', 'must', 'all'),
#  ('must', 'all', 'use'),
#  ('all', 'use', '...'),
#  ('use', '...', '14'),
#  ('...', '14', 'b"Don\'t'),
#  ('14', 'b"Don\'t', 'know'),
#  ('b"Don\'t', 'know', 'about'),
#  ('know', 'about', 'football,'),
#  ('about', 'football,', 'but'),
#  ('football,', 'but', 'Manchester'),
#  ('but', 'Manchester', 'wa...'),
#  ('Manchester', 'wa...', '15'),
#  ('wa...', '15', "b'Out"),
#  ('15', "b'Out", 'and'),
#  ("b'Out", 'and', 'about'),
#  ('and', 'about', 'in'),
#  ('about', 'in', 'mancheste'),
#  ('in', 'mancheste', '16'),
#  ('mancheste', '16', "b'Loved"),
#  ('16', "b'Loved", 'the'),
#  ("b'Loved", 'the', 'gold'),
#  ('the', 'gold', '&amp;'),
#  ('gold', '&amp;', 'white'),
#  ('&amp;', 'white', 'combination'),
#  ('white', 'combination', 'on'),
#  ('combination', 'on', 'th...'),
#  ('on', 'th...', '17'),
#  ('th...', '17', "b'No"),
#  ('17', "b'No", 'days'),
#  ("b'No", 'days', 'off'),
#  ('days', 'off', '\\xf0\\x9f\\x92\\xaa\\xf0\\x9f\\x8f\\x8b...'),
#  ('off', '\\xf0\\x9f\\x92\\xaa\\xf0\\x9f\\x8f\\x8b...', '18'),
#  ('\\xf0\\x9f\\x92\\xaa\\xf0\\x9f\\x8f\\x8b...', '18', "b'B"),
#  ('18', "b'B", '19'),
#  ("b'B", '19', "b'@E"),
#  ('19', "b'@E", '20'),
#  ("b'@E", '20', "b'@Vyyype"),
#  ('20', "b'@Vyyype", '21'),
#  ("b'@Vyyype", '21', "b'@jacksonhvisuals"),
#  ('21', "b'@jacksonhvisuals", 'Eve'),
#  ("b'@jacksonhvisuals", 'Eve', '22'),
#  ('Eve', '22', "b'@sa"),
#  ('22', "b'@sa", '23'),
#  ("b'@sa", '23', 'b"NEW'),
#  ('23', 'b"NEW', 'VIDEO'),
#  ('b"NEW', 'VIDEO', '-'),
#  ('VIDEO', '-', "What's"),
#  ('-', "What's", 'in'),
#  ("What's", 'in', 'my'),
#  ('in', 'my', 'Tech'),
#  ('my', 'Tech', 'Bag!'),
#  ('Tech', 'Bag!', '[2019]'),
#  ('Bag!', '[2019]', 'ht...'),
#  ('[2019]', 'ht...', '24'),
#  ('ht...', '24', "b'Uploading\\xe2\\x80\\xa6'"),
#  ('24', "b'Uploading\\xe2\\x80\\xa6'", '25'),
#  ("b'Uploading\\xe2\\x80\\xa6'", '25', "b'@ZacksJe"),
#  ('25', "b'@ZacksJe", '26'),
#  ("b'@ZacksJe", '26', "b'@thephysicsgi"),
#  ('26', "b'@thephysicsgi", '27'),
#  ("b'@thephysicsgi", '27', "b'@Cobinja"),
#  ('27', "b'@Cobinja", "Run.'"),
#  ("b'@Cobinja", "Run.'", '28'),
#  ("Run.'", '28', "b'@swoonbergh"),
#  ('28', "b'@swoonbergh", 'Stock,'),
#  ("b'@swoonbergh", 'Stock,', 'primary'),
#  ('Stock,', 'primary', "lens'"),
#  ('primary', "lens'", '29'),
#  ("lens'", '29', "b'@SnazzyQ"),
#  ('29', "b'@SnazzyQ", 'I'),
#  ("b'@SnazzyQ", 'I', 'keep'),
#  ('I', 'keep', 'a'),
#  ('keep', 'a', 'squeegie'),
#  ('a', 'squeegie', 'in'),
#  ('squeegie', 'in', 'my'),
#  ('in', 'my', 'ca'),
#  ('my', 'ca', '30'),
#  ('ca', '30', "b'F"),
#  ('30', "b'F", '31'),
#  ("b'F", '31', "b'@thephysicsgi"),
#  ('31', "b'@thephysicsgi", '32'),
#  ("b'@thephysicsgi", '32', "b'Amazon"),
#  ('32', "b'Amazon", 'P'),
#  ("b'Amazon", 'P', '33'),
#  ('P', '33', "b'@sskameshtwit"),
#  ('33', "b'@sskameshtwit", '@mondobytes'),
#  ("b'@sskameshtwit", '@mondobytes', '@RED_Cinema'),
#  ('@mondobytes', '@RED_Cinema', 'https:...'),
#  ('@RED_Cinema', 'https:...', '34'),
#  ('https:...', '34', "b'@"),
#  ('34', "b'@", '35'),
#  ("b'@", '35', "b'@nickelslol"),
#  ('35', "b'@nickelslol", 'These'),
#  ("b'@nickelslol", 'These', 'people'),
#  ('These', 'people', 'a'),
#  ('people', 'a', '36'),
#  ('a', '36', "b'@"),
#  ('36', "b'@", '37'),
#  ("b'@", '37', "b'@"),
#  ('37', "b'@", '38'),
#  ("b'@", '38', "b'The"),
#  ('38', "b'The", 'pe'),
#  ("b'The", 'pe', '39'),
#  ('pe', '39', 'b"@samsheffer'),
#  ('39', 'b"@samsheffer', '@Casey'),
#  ('b"@samsheffer', '@Casey', '@piamuehlenbeck'),
#  ('@Casey', '@piamuehlenbeck', 'If'),
#  ('@piamuehlenbeck', 'If', "you're..."),
#  ('If', "you're...", '40'),
#  ("you're...", '40', "b'Gamers:"),
#  ('40', "b'Gamers:", 'We'),
#  ("b'Gamers:", 'We', 'like'),
#  ('We', 'like', 'high'),
#  ('like', 'high', 'end'),
#  ('high', 'end', 'specs\\n\\nAsus:'),
#  ('end', 'specs\\n\\nAsus:', 'Say'),
#  ('specs\\n\\nAsus:', 'Say', '...'),
#  ('Say', '...', '41'),
#  ('...', '41', 'b"RT'),
#  ('41', 'b"RT', '@empireultimate:'),
#  ('b"RT', '@empireultimate:', 'EMPIRE'),
#  ('@empireultimate:', 'EMPIRE', 'WINS!!!'),
#  ('EMPIRE', 'WINS!!!', "We're"),
#  ('WINS!!!', "We're", 'goi...'),
#  ("We're", 'goi...', '42'),
#  ('goi...', '42', 'b"@austinnotduncan'),
#  ('42', 'b"@austinnotduncan', "Can't"),
#  ('b"@austinnotduncan', "Can't", 'forget'),
#  ("Can't", 'forget', 'occasional'),
#  ('forget', 'occasional', 'hur...'),
#  ('occasional', 'hur...', '43'),
#  ('hur...', '43', 'b"@stshank'),
#  ('43', 'b"@stshank', '@wunderground'),
#  ('b"@stshank', '@wunderground', 'First'),
#  ('@wunderground', 'First', 'one.'),
#  ('First', 'one.', "I'm"),
#  ('one.', "I'm", 'in'),
#  ("I'm", 'in', 'tra...'),
#  ('in', 'tra...', '44'),
#  ('tra...', '44', 'b"SHEESH'),
#  ('44', 'b"SHEESH', "it's"),
#  ('b"SHEESH', "it's", 'hot'),
#  ("it's", 'hot', 'out'),
#  ('hot', 'out', 'here'),
#  ('out', 'here', 'in'),
#  ('here', 'in', 'these'),
#  ('in', 'these', 'streets.'),
#  ('these', 'streets.', 'h...'),
#  ('streets.', 'h...', '45'),
#  ('h...', '45', "b'RT"),
#  ('45', "b'RT", '@MKBHD:'),
#  ("b'RT", '@MKBHD:', 'NEW'),
#  ('@MKBHD:', 'NEW', 'VIDEO'),
#  ('NEW', 'VIDEO', '-'),
#  ('VIDEO', '-', 'The'),
#  ('-', 'The', 'Last'),
#  ('The', 'Last', '(and'),
#  ('Last', '(and', 'Fi'),
#  ('(and', 'Fi', '46'),
#  ('Fi', '46', "b'@YagnaPatel9"),
#  ('46', "b'@YagnaPatel9", 'So'),
#  ("b'@YagnaPatel9", 'So', "good'"),
#  ('So', "good'", '47'),
#  ("good'", '47', "b'@B"),
#  ('47', "b'@B", '48'),
#  ("b'@B", '48', 'b"Ok'),
#  ('48', 'b"Ok', "I'm"),
#  ('b"Ok', "I'm", 'not'),
#  ("I'm", 'not', 'even'),
#  ('not', 'even', 'a'),
#  ('even', 'a', 'cat'),
#  ('a', 'cat', 'person'),
#  ('cat', 'person', 'but'),
#  ('person', 'but', 'honestly'),
#  ('but', 'honestly', 'th...'),
#  ('honestly', 'th...', '49'),
#  ('th...', '49', 'b\'"Being'),
#  ('49', 'b\'"Being', 'first'),
#  ('b\'"Being', 'first', "doesn\\'t"),
#  ('first', "doesn\\'t", 'matter'),
#  ("doesn\\'t", 'matter', 'if'),
#  ('matter', 'if', 'it'),
#  ('if', 'it', 'sucks"'),
#  ('it', 'sucks"', '-'),
#  ('sucks"', '-', '...'),
#  ('-', '...', '50'),
#  ('...', '50', "b'TWEETS"),
#  ('50', "b'TWEETS", 'BUT'),
#  ("b'TWEETS", 'BUT', 'WITH'),
#  ('BUT', 'WITH', "EDITING'"),
#  ('WITH', "EDITING'", '51'),
#  ("EDITING'", '51', 'b"@KTasterisk'),
#  ('51', 'b"@KTasterisk', 'I'),
#  ('b"@KTasterisk', 'I', "can't"),
#  ('I', "can't", 'disagree"'),
#  ("can't", 'disagree"', '52'),
#  ('disagree"', '52', "b'@abhishek1point0"),
#  ('52', "b'@abhishek1point0", 'This'),
#  ("b'@abhishek1point0", 'This', 'is'),
#  ('This', 'is', 'all'),
#  ('is', 'all', 'fantastic'),
#  ('all', 'fantastic', 'logic...'),
#  ('fantastic', 'logic...', '53'),
#  ('logic...', '53', "b'RT"),
#  ('53', "b'RT", '@zivbuzaglo:'),
#  ("b'RT", '@zivbuzaglo:', 'B'),
#  ('@zivbuzaglo:', 'B', '54'),
#  ('B', '54', "b'@supe"),
#  ('54', "b'@supe", '55'),
#  ("b'@supe", '55', "b'@SalahEl_Deen"),
#  ('55', "b'@SalahEl_Deen", "\\xf0\\x9f\\x98\\x85'"),
#  ("b'@SalahEl_Deen", "\\xf0\\x9f\\x98\\x85'", '56'),
#  ("\\xf0\\x9f\\x98\\x85'", '56', "b'NEW"),
#  ('56', "b'NEW", 'VIDEO'),
#  ("b'NEW", 'VIDEO', '-'),
#  ('VIDEO', '-', 'The'),
#  ('-', 'The', 'Last'),
#  ('The', 'Last', '(and'),
#  ('Last', '(and', 'Fi'),
#  ('(and', 'Fi', '57'),
#  ('Fi', '57', "b'\\xf0\\x9f\\x94\\xa5"),
#  ('57', "b'\\xf0\\x9f\\x94\\xa5", 'Uploading\\xe2\\x80\\xa6'),
#  ("b'\\xf0\\x9f\\x94\\xa5", 'Uploading\\xe2\\x80\\xa6', '\\xf0\\...'),
#  ('Uploading\\xe2\\x80\\xa6', '\\xf0\\...', '58'),
#  ('\\xf0\\...', '58', 'b"AirPower'),
#  ('58', 'b"AirPower', 'Award'),
#  ('b"AirPower', 'Award', '2019'),
#  ('Award', '2019', 'goes'),
#  ('2019', 'goes', 'to:'),
#  ('goes', 'to:', 'Bixby'),
#  ('to:', 'Bixby', 'speaker'),
#  ('Bixby', 'speaker', '\\...'),
#  ('speaker', '\\...', 't'),
#  ('\\...', 't', 'ove'),
#  ('t', 'ove', '\\'),
#  ('ove', '\\', '0'),
#  ('\\', '0', 'eat'),
#  ('0', 'eat', 'show'),
#  ('eat', 'show', 'by'),
#  ('show', 'by', 'both'),
#  ('by', 'both', 'the'),
#  ('both', 'the', 'teams'),
#  ('the', 'teams', 'in'),
#  ('teams', 'in', 'the'),
#  ('in', 'the', '#CWC19Finals...'),
#  ('the', '#CWC19Finals...', '1'),
#  ('#CWC19Finals...', '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 'stly'),
#  ('2', 'stly', 'I'),
#  ('stly', 'I', 'want'),
#  ('I', 'want', 'to'),
#  ('want', 'to', 'thank'),
#  ('to', 'thank', 'all'),
#  ('thank', 'all', 'ou'),
#  ('all', 'ou', '3'),
#  ('ou', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'oud'),
#  ('4', 'oud', 'of'),
#  ('oud', 'of', 'the'),
#  ('of', 'the', 'cha'),
#  ('the', 'cha', '5'),
#  ('cha', '5', 'ound'),
#  ('5', 'ound', '\\xf0\\x9f\\x99\\x82.'),
#  ('ound', '\\xf0\\x9f\\x99\\x82.', 'Being'),
#  ('\\xf0\\x9f\\x99\\x82.', 'Being', 'able'),
#  ('Being', 'able', 'to'),
#  ('able', 'to', 'inspi'),
#  ('to', 'inspi', '6'),
#  ('inspi', '6', 'NaN'),
#  ('6', 'NaN', '7'),
#  ('NaN', '7', 'and'),
#  ('7', 'and', 'M'),
#  ('and', 'M', '8'),
#  ('M', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'ch'),
#  ('11', 'ch', 'on.'),
#  ('ch', 'on.', 'Jai'),
#  ('on.', 'Jai', 'hind'),
#  ('Jai', 'hind', '\\xf0\\x9f\\x87\\xae\\xf0\\x9f\\x87\\x...'),
#  ('hind', '\\xf0\\x9f\\x87\\xae\\xf0\\x9f\\x87\\x...', '12'),
#  ('\\xf0\\x9f\\x87\\xae\\xf0\\x9f\\x87\\x...', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', 'yone'),
#  ('13', 'yone', '\\xf0\\x9f\\xa4\\x9d\\xe2\\x9c\\x8c'),
#  ('yone', '\\xf0\\x9f\\xa4\\x9d\\xe2\\x9c\\x8c', 'https://t.co...'),
#  ('\\xf0\\x9f\\xa4\\x9d\\xe2\\x9c\\x8c', 'https://t.co...', '14'),
#  ('https://t.co...', '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', '\\xf0\\x9f\\x98\\x8e'),
#  ('15', '\\xf0\\x9f\\x98\\x8e', "https://t.co/QbcjS5VORD'"),
#  ('\\xf0\\x9f\\x98\\x8e', "https://t.co/QbcjS5VORD'", '16'),
#  ("https://t.co/QbcjS5VORD'", '16', 'icket'),
#  ('16', 'icket', 'has'),
#  ('icket', 'has', 'anothe'),
#  ('has', 'anothe', '17'),
#  ('anothe', '17', 'dwo'),
#  ('17', 'dwo', '18'),
#  ('dwo', '18', 'eakfast'),
#  ('18', 'eakfast', 'alongside'),
#  ('eakfast', 'alongside', 'some'),
#  ('alongside', 'some', 'good'),
#  ('some', 'good', 'fellas'),
#  ('good', 'fellas', '\\xf0\\x9f\\xa...'),
#  ('fellas', '\\xf0\\x9f\\xa...', '19'),
#  ('\\xf0\\x9f\\xa...', '19', 'ikTilden'),
#  ('19', 'ikTilden', 'I'),
#  ('ikTilden', 'I', 'take'),
#  ('I', 'take', 'matte'),
#  ('take', 'matte', 'black'),
#  ('matte', 'black', 'eve'),
#  ('black', 'eve', '20'),
#  ('eve', '20', 'The'),
#  ('20', 'The', 'c'),
#  ('The', 'c', '21'),
#  ('c', '21', 'yone'),
#  ('21', 'yone', 'knows'),
#  ('yone', 'knows', 'the'),
#  ('knows', 'the', 'thiccest'),
#  ('the', 'thiccest', 'lens'),
#  ('thiccest', 'lens', 'p'),
#  ('lens', 'p', '22'),
#  ('p', '22', 'adietschy'),
#  ('22', 'adietschy', 'Legit'),
#  ('adietschy', 'Legit', 'weighs'),
#  ('Legit', 'weighs', 'twice'),
#  ('weighs', 'twice', 'as'),
#  ('twice', 'as', 'much'),
#  ('as', 'much', 'as'),
#  ('much', 'as', 'the'),
#  ('as', 'the', 'ac...'),
#  ('the', 'ac...', '23'),
#  ('ac...', '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'NaN'),
#  ('25', 'NaN', '26'),
#  ('NaN', '26', 'l'),
#  ('26', 'l', 'That'),
#  ('l', 'That', 'thousand'),
#  ('That', 'thousand', 'ya'),
#  ('thousand', 'ya', '27'),
#  ('ya', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', 'NaN'),
#  ('29', 'NaN', '30'),
#  ('NaN', '30', 'om'),
#  ('30', 'om', 'OnePlus'),
#  ('om', 'OnePlus', '7'),
#  ('OnePlus', '7', 'P'),
#  ('7', 'P', '31'),
#  ('P', '31', 'l'),
#  ('31', 'l', "Same'"),
#  ('l', "Same'", '32'),
#  ("Same'", '32', 'ime'),
#  ('32', 'ime', 'Day'),
#  ('ime', 'Day', '2019'),
#  ('Day', '2019', "https://t.co/idIUX6xuce'"),
#  ('2019', "https://t.co/idIUX6xuce'", '33'),
#  ("https://t.co/idIUX6xuce'", '33', 'NaN'),
#  ('33', 'NaN', '34'),
#  ('NaN', '34', 'eckless'),
#  ('34', 'eckless', 'My'),
#  ('eckless', 'My', 'subtle'),
#  ('My', 'subtle', 'hint'),
#  ('subtle', 'hint', '35'),
#  ('hint', '35', 'e'),
#  ('35', 'e', '36'),
#  ('e', '36', 'edial_12'),
#  ('36', 'edial_12', "Damn'"),
#  ('edial_12', "Damn'", '37'),
#  ("Damn'", '37', 'eckless'),
#  ('37', 'eckless', 'Si'),
#  ('eckless', 'Si', '38'),
#  ('Si', '38', 'son'),
#  ('38', 'son', 'next'),
#  ('son', 'next', 'to'),
#  ('next', 'to', 'me'),
#  ('to', 'me', 'on'),
#  ('me', 'on', 'this'),
#  ('on', 'this', 'flight'),
#  ('this', 'flight', 'has'),
#  ('flight', 'has', 'been'),
#  ('has', 'been', 'watchin...'),
#  ('been', 'watchin...', '39'),
#  ('watchin...', '39', 'NaN'),
#  ('39', 'NaN', '40'),
#  ('NaN', '40', 'NaN'),
#  ('40', 'NaN', '41'),
#  ('NaN', '41', 'NaN'),
#  ('41', 'NaN', '42'),
#  ('NaN', '42', 'NaN'),
#  ('42', 'NaN', '43'),
#  ('NaN', '43', 'NaN'),
#  ('43', 'NaN', '44'),
#  ('NaN', '44', 'NaN'),
#  ('44', 'NaN', '45'),
#  ('NaN', '45', 'st)'),
#  ('45', 'st)', 'Folding'),
#  ('st)', 'Folding', 'Phone!'),
#  ('Folding', 'Phone!', 'https://t.co/jwDCcdHTQd'),
#  ('Phone!', 'https://t.co/jwDCcdHTQd', '-'),
#  ('https://t.co/jwDCcdHTQd', '-', 'R...'),
#  ('-', 'R...', '46'),
#  ('R...', '46', 'NaN'),
#  ('46', 'NaN', '47'),
#  ('NaN', '47', 'andon_Y_Lee'),
#  ('47', 'andon_Y_Lee', "Yes'"),
#  ('andon_Y_Lee', "Yes'", '48'),
#  ("Yes'", '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'o......\\n@MKBHD'),
#  ('53', 'o......\\n@MKBHD', "https://t.co/QbynjD4q2H'"),
#  ('o......\\n@MKBHD', "https://t.co/QbynjD4q2H'", '54'),
#  ("https://t.co/QbynjD4q2H'", '54', 'scientific'),
#  ('54', 'scientific', 'Fi'),
#  ('scientific', 'Fi', '55'),
#  ('Fi', '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'st)'),
#  ('56', 'st)', 'Folding'),
#  ('st)', 'Folding', 'Phone!'),
#  ('Folding', 'Phone!', 'https://t.co/jwDCcdHTQd'),
#  ('Phone!', 'https://t.co/jwDCcdHTQd', '-'),
#  ('https://t.co/jwDCcdHTQd', '-', 'R...'),
#  ('-', 'R...', '57'),
#  ('R...', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ('58', 'NaN', '5'),
#  ('NaN', '5', 'hou'),
#  ('5', 'hou', '\\'),
#  ('hou', '\\', '0'),
#  ('\\', '0', 'day.'),
#  ('0', 'day.', 'Cong'),
#  ('day.', 'Cong', '1'),
#  ('Cong', '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 'fans'),
#  ('2', 'fans', 'who'),
#  ('fans', 'who', 'came'),
#  ('who', 'came', 'in'),
#  ('came', 'in', 'huge'),
#  ('in', 'huge', 'numbe'),
#  ('huge', 'numbe', '3'),
#  ('numbe', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'acte'),
#  ('4', 'acte', '5'),
#  ('acte', '5', 'e'),
#  ('5', 'e', 'the'),
#  ('e', 'the', 'futu'),
#  ('the', 'futu', '6'),
#  ('futu', '6', 'y.'),
#  ('6', 'y.', 'Chee'),
#  ('y.', 'Chee', '7'),
#  ('Chee', '7', 's'),
#  ('7', 's', '\\xf0\\x9f\\x92\\x91\\xe2\\x9d\\xa4'),
#  ('s', '\\xf0\\x9f\\x92\\x91\\xe2\\x9d\\xa4', 'https://t.co/GR...'),
#  ('\\xf0\\x9f\\x92\\x91\\xe2\\x9d\\xa4', 'https://t.co/GR...', '8'),
#  ('https://t.co/GR...', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'NaN'),
#  ('11', 'NaN', '12'),
#  ('NaN', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', "IQUS'"),
#  ('13', "IQUS'", '14'),
#  ("IQUS'", '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', 'NaN'),
#  ('15', 'NaN', '16'),
#  ('NaN', '16', 'c'),
#  ('16', 'c', '17'),
#  ('c', '17', 'k.'),
#  ('17', 'k.', "https://t.co/o22H1XdzHc'"),
#  ('k.', "https://t.co/o22H1XdzHc'", '18'),
#  ("https://t.co/o22H1XdzHc'", '18', 'ogn'),
#  ('18', 'ogn', '#basushanke'),
#  ('ogn', '#basushanke', '19'),
#  ('#basushanke', '19', 'ything'),
#  ('19', 'ything', 've'),
#  ('ything', 've', '20'),
#  ('ve', '20', 'op'),
#  ('20', 'op', '21'),
#  ('op', '21', 'oduces'),
#  ('21', 'oduces', 'the'),
#  ('oduces', 'the', 'sha'),
#  ('the', 'sha', '22'),
#  ('sha', '22', 'a'),
#  ('22', 'a', "hah'"),
#  ('a', "hah'", '23'),
#  ("hah'", '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'yRig'),
#  ('25', 'yRig', '@whatsinside'),
#  ('yRig', '@whatsinside', 'Eve'),
#  ('@whatsinside', 'Eve', '26'),
#  ('Eve', '26', 'd'),
#  ('26', 'd', 'sta'),
#  ('d', 'sta', '27'),
#  ('sta', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', "y-on'"),
#  ('29', "y-on'", '30'),
#  ("y-on'", '30', 'o'),
#  ('30', 'o', 'th'),
#  ('o', 'th', '31'),
#  ('th', '31', 'NaN'),
#  ('31', 'NaN', '32'),
#  ('NaN', '32', 'NaN'),
#  ('32', 'NaN', '33'),
#  ('NaN', '33', 'NaN'),
#  ('33', 'NaN', '34'),
#  ('NaN', '34', 'ight'),
#  ('34', 'ight', 'now'),
#  ('ight', 'now', 'is'),
#  ('now', 'is', 'constantly'),
#  ('is', 'constantly', '35'),
#  ('constantly', '35', 'eally'),
#  ('35', 'eally', 'out'),
#  ('eally', 'out', 'he'),
#  ('out', 'he', '36'),
#  ('he', '36', 'NaN'),
#  ('36', 'NaN', '37'),
#  ('NaN', '37', 'did'),
#  ('37', 'did', 'you'),
#  ('did', 'you', 'know'),
#  ('you', 'know', 'you'),
#  ('know', 'you', '38'),
#  ('you', '38', 'e'),
#  ('38', 'e', 'widesc'),
#  ('e', 'widesc', '39'),
#  ('widesc', '39', 'NaN'),
#  ('39', 'NaN', '40'),
#  ('NaN', '40', 'NaN'),
#  ('40', 'NaN', '41'),
#  ('NaN', '41', 'NaN'),
#  ('41', 'NaN', '42'),
#  ('NaN', '42', 'NaN'),
#  ('42', 'NaN', '43'),
#  ('NaN', '43', 'NaN'),
#  ('43', 'NaN', '44'),
#  ('NaN', '44', 'NaN'),
#  ('44', 'NaN', '45'),
#  ('NaN', '45', 'NaN'),
#  ('45', 'NaN', '46'),
#  ('NaN', '46', 'NaN'),
#  ('46', 'NaN', '47'),
#  ('NaN', '47', 'NaN'),
#  ('47', 'NaN', '48'),
#  ('NaN', '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'NaN'),
#  ('53', 'NaN', '54'),
#  ('NaN', '54', "e'"),
#  ('54', "e'", '55'),
#  ("e'", '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'NaN'),
#  ('56', 'NaN', '57'),
#  ('NaN', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ('58', 'NaN', 's'),
#  ('NaN', 's', 'at'),
#  ('s', 'at', 'the'),
#  ('at', 'the', '@Wimbledon'),
#  ('the', '@Wimbledon', 'final'),
#  ('@Wimbledon', 'final', 'yeste'),
#  ('final', 'yeste', '\\'),
#  ('yeste', '\\', '0'),
#  ('\\', '0', 'atulations'),
#  ('0', 'atulations', '@englandc'),
#  ('atulations', '@englandc', '1'),
#  ('@englandc', '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 's'),
#  ('2', 's', 'to'),
#  ('s', 'to', 'suppo'),
#  ('to', 'suppo', '3'),
#  ('suppo', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'shown'),
#  ('4', 'shown', 'by'),
#  ('shown', 'by', 'the'),
#  ('by', 'the', 'boys'),
#  ('the', 'boys', '\\xf0\\x9f\\x92\\xaf\\xf0\\x9f\\x9...'),
#  ('boys', '\\xf0\\x9f\\x92\\xaf\\xf0\\x9f\\x9...', '5'),
#  ('\\xf0\\x9f\\x92\\xaf\\xf0\\x9f\\x9...', '5', 'e'),
#  ('5', 'e', 'gene'),
#  ('e', 'gene', '6'),
#  ('gene', '6', 's'),
#  ('6', 's', 'and'),
#  ('s', 'and', 'thank'),
#  ('and', 'thank', 'you'),
#  ('thank', 'you', 'fo'),
#  ('you', 'fo', '7'),
#  ('fo', '7', 'NaN'),
#  ('7', 'NaN', '8'),
#  ('NaN', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'NaN'),
#  ('11', 'NaN', '12'),
#  ('NaN', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', 'NaN'),
#  ('13', 'NaN', '14'),
#  ('NaN', '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', 'NaN'),
#  ('15', 'NaN', '16'),
#  ('NaN', '16', 'icket'),
#  ('16', 'icket', 'shoe'),
#  ('icket', 'shoe', 'fo'),
#  ('shoe', 'fo', '17'),
#  ('fo', '17', 'NaN'),
#  ('17', 'NaN', '18'),
#  ('NaN', '18', '@vijayshanka'),
#  ('18', '@vijayshanka', '19'),
#  ('@vijayshanka', '19', 'y'),
#  ('19', 'y', 'se'),
#  ('y', 'se', '20'),
#  ('se', '20', 'eally'),
#  ('20', 'eally', 'does'),
#  ('eally', 'does', '21'),
#  ('does', '21', 'pest'),
#  ('21', 'pest', "image'"),
#  ('pest', "image'", '22'),
#  ("image'", '22', 'NaN'),
#  ('22', 'NaN', '23'),
#  ('NaN', '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'yone'),
#  ('25', 'yone', 'knows'),
#  ('yone', 'knows', 'Tacomas'),
#  ('knows', 'Tacomas', 'neve'),
#  ('Tacomas', 'neve', '26'),
#  ('neve', '26', 'e'),
#  ('26', 'e', 'on'),
#  ('e', 'on', 'Mac'),
#  ('on', 'Mac', '(to'),
#  ('Mac', '(to', 'the'),
#  ('(to', 'the', 't'),
#  ('the', 't', '27'),
#  ('t', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', 'NaN'),
#  ('29', 'NaN', '30'),
#  ('NaN', '30', 'ough'),
#  ('30', 'ough', 'a'),
#  ('ough', 'a', 'clean'),
#  ('a', 'clean', 'ai'),
#  ('clean', 'ai', '31'),
#  ('ai', '31', 'NaN'),
#  ('31', 'NaN', '32'),
#  ('NaN', '32', 'NaN'),
#  ('32', 'NaN', '33'),
#  ('NaN', '33', 'NaN'),
#  ('33', 'NaN', '34'),
#  ('NaN', '34', 'otating'),
#  ('34', 'otating', 'my'),
#  ('otating', 'my', 'iPad'),
#  ('my', 'iPad', 'back'),
#  ('iPad', 'back', 'and'),
#  ('back', 'and', 'fo'),
#  ('and', 'fo', '35'),
#  ('fo', '35', 'e'),
#  ('35', 'e', 'squinting'),
#  ('e', 'squinting', 'fo'),
#  ('squinting', 'fo', '36'),
#  ('fo', '36', 'NaN'),
#  ('36', 'NaN', '37'),
#  ('NaN', '37', 'iPad'),
#  ('37', 'iPad', 'has'),
#  ('iPad', 'has', 'this'),
#  ('has', 'this', 'neat'),
#  ('this', 'neat', 'function'),
#  ('neat', 'function', 'that'),
#  ('function', 'that', 'makes'),
#  ('that', 'makes', 'movies...'),
#  ('makes', 'movies...', '38'),
#  ('movies...', '38', 'een'),
#  ('38', 'een', 'movie'),
#  ('een', 'movie', 'on'),
#  ('movie', 'on', 'his'),
#  ('on', 'his', 'iPad...'),
#  ('his', 'iPad...', 'but'),
#  ('iPad...', 'but', 'holding'),
#  ('but', 'holding', 'it'),
#  ('holding', 'it', 've'),
#  ('it', 've', '39'),
#  ('ve', '39', 'NaN'),
#  ('39', 'NaN', '40'),
#  ('NaN', '40', 'NaN'),
#  ('40', 'NaN', '41'),
#  ('NaN', '41', 'NaN'),
#  ('41', 'NaN', '42'),
#  ('NaN', '42', 'NaN'),
#  ('42', 'NaN', '43'),
#  ('NaN', '43', 'NaN'),
#  ('43', 'NaN', '44'),
#  ('NaN', '44', 'NaN'),
#  ('44', 'NaN', '45'),
#  ('NaN', '45', 'NaN'),
#  ('45', 'NaN', '46'),
#  ('NaN', '46', 'NaN'),
#  ('46', 'NaN', '47'),
#  ('NaN', '47', 'NaN'),
#  ('47', 'NaN', '48'),
#  ('NaN', '48', 'NaN'),
#  ('48', 'NaN', '49'),
#  ('NaN', '49', 'NaN'),
#  ('49', 'NaN', '50'),
#  ('NaN', '50', 'NaN'),
#  ('50', 'NaN', '51'),
#  ('NaN', '51', 'NaN'),
#  ('51', 'NaN', '52'),
#  ('NaN', '52', 'NaN'),
#  ('52', 'NaN', '53'),
#  ('NaN', '53', 'NaN'),
#  ('53', 'NaN', '54'),
#  ('NaN', '54', 'NaN'),
#  ('54', 'NaN', '55'),
#  ('NaN', '55', 'NaN'),
#  ('55', 'NaN', '56'),
#  ('NaN', '56', 'NaN'),
#  ('56', 'NaN', '57'),
#  ('NaN', '57', 'NaN'),
#  ('57', 'NaN', '58'),
#  ('NaN', '58', 'NaN'),
#  ('58', 'NaN', 'day.'),
#  ('NaN', 'day.', 'Shee'),
#  ('day.', 'Shee', '\\'),
#  ('Shee', '\\', '0'),
#  ('\\', '0', 'icket.'),
#  ('0', 'icket.', "\\xf0\\x9f\\x91\\x8d\\xf0\\x9f\\x8f\\xbc'"),
#  ('icket.', "\\xf0\\x9f\\x91\\x8d\\xf0\\x9f\\x8f\\xbc'", '1'),
#  ("\\xf0\\x9f\\x91\\x8d\\xf0\\x9f\\x8f\\xbc'", '1', 'NaN'),
#  ('1', 'NaN', '2'),
#  ('NaN', '2', 't'),
#  ('2', 't', 'the'),
#  ('t', 'the', 'team.'),
#  ('the', 'team.', 'You'),
#  ('team.', 'You', 'made'),
#  ('You', 'made', 'it'),
#  ('made', 'it', 'a'),
#  ('it', 'a', 'memo'),
#  ('a', 'memo', '3'),
#  ('memo', '3', 'NaN'),
#  ('3', 'NaN', '4'),
#  ('NaN', '4', 'NaN'),
#  ('4', 'NaN', '5'),
#  ('NaN', '5', 'ation'),
#  ('5', 'ation', 'is'),
#  ('ation', 'is', 'a'),
#  ('is', 'a', 'blessing.'),
#  ('a', 'blessing.', '\\xf0\\x9f\\x98\\x87'),
#  ('blessing.', '\\xf0\\x9f\\x98\\x87', 'https://...'),
#  ('\\xf0\\x9f\\x98\\x87', 'https://...', '6'),
#  ('https://...', '6', 'you'),
#  ('6', 'you', '7'),
#  ('you', '7', 'NaN'),
#  ('7', 'NaN', '8'),
#  ('NaN', '8', 'NaN'),
#  ('8', 'NaN', '9'),
#  ('NaN', '9', 'NaN'),
#  ('9', 'NaN', '10'),
#  ('NaN', '10', 'NaN'),
#  ('10', 'NaN', '11'),
#  ('NaN', '11', 'NaN'),
#  ('11', 'NaN', '12'),
#  ('NaN', '12', 'NaN'),
#  ('12', 'NaN', '13'),
#  ('NaN', '13', 'NaN'),
#  ('13', 'NaN', '14'),
#  ('NaN', '14', 'NaN'),
#  ('14', 'NaN', '15'),
#  ('NaN', '15', 'NaN'),
#  ('15', 'NaN', '16'),
#  ('NaN', '16', 'you'),
#  ('16', 'you', 'inspi'),
#  ('you', 'inspi', '17'),
#  ('inspi', '17', 'NaN'),
#  ('17', 'NaN', '18'),
#  ('NaN', '18', '260'),
#  ('18', '260', "https://t.co/ppc0tHJ1FB'"),
#  ('260', "https://t.co/ppc0tHJ1FB'", '19'),
#  ("https://t.co/ppc0tHJ1FB'", '19', "iously'"),
#  ('19', "iously'", '20'),
#  ("iously'", '20', 'uin'),
#  ('20', 'uin', 'its'),
#  ('uin', 'its', 'chances'),
#  ('its', 'chances', 'as'),
#  ('chances', 'as', 'a'),
#  ('as', 'a', 'vlog'),
#  ('a', 'vlog', 'came'),
#  ('vlog', 'came', '21'),
#  ('came', '21', 'NaN'),
#  ('21', 'NaN', '22'),
#  ('NaN', '22', 'NaN'),
#  ('22', 'NaN', '23'),
#  ('NaN', '23', 'NaN'),
#  ('23', 'NaN', '24'),
#  ('NaN', '24', 'NaN'),
#  ('24', 'NaN', '25'),
#  ('NaN', '25', 'have'),
#  ('25', 'have', 'p'),
#  ('have', 'p', '26'),
#  ('p', '26', 'eats'),
#  ('26', 'eats', 'behind'),
#  ('eats', 'behind', 'the'),
#  ('behind', 'the', 'came'),
#  ('the', 'came', '27'),
#  ('came', '27', 'NaN'),
#  ('27', 'NaN', '28'),
#  ('NaN', '28', 'NaN'),
#  ('28', 'NaN', '29'),
#  ('NaN', '29', 'NaN'),
#  ('29', 'NaN', '30'),
#  ('NaN', '30', 'plane'),
#  ('30', 'plane', 'window'),
#  ('plane', 'window', '\\xe2\\x9c\\x88\\xef\\xb8\\x8f\\xf0\\x9f\\...'),
#  ('window', '\\xe2\\x9c\\x88\\xef\\xb8\\x8f\\xf0\\x9f\\...', '31'),
#  ('\\xe2\\x9c\\x88\\xef\\xb8\\x8f\\xf0\\x9f\\...', '31', 'NaN'),
#  ('31', 'NaN', '32'),
#  ('NaN', '32', 'NaN'),
#  ('32', 'NaN', '33'),
#  ('NaN', '33', 'NaN'),
#  ('33', 'NaN', '34'),
#  ('NaN', '34', 'th'),
#  ('34', 'th', 'while'),
#  ('th', 'while', 'sitting'),
#  ('while', 'sitting', 'next'),
#  ('sitting', 'next', 'to'),
#  ('next', 'to', 'him'),
#  ('to', 'him', 'to'),
#  ('him', 'to', 'subco\\xe2\\x80\\...'),
#  ('to', 'subco\\xe2\\x80\\...', '35'),
#  ('subco\\xe2\\x80\\...', '35', 'hou'),
#  ('35', 'hou', '36'),
#  ('hou', '36', 'NaN'),
#  ('36', 'NaN', '37'),
#  ('NaN', '37', 'so'),
#  ('37', 'so', 'you'),
#  ('so', 'you', 'don\\xe2\\x80\\x99t'),
#  ('you', 'don\\xe2\\x80\\x99t', 'have'),
#  ('don\\xe2\\x80\\x99t', 'have', 'to'),
#  ('have', 'to', 'squint'),
#  ('to', 'squint', 'fo'),
#  ('squint', 'fo', '38'),
#  ('fo', '38', '\\xe2\\x80\\xa6'),
#  ('38', '\\xe2\\x80\\xa6', "https://t.co/sPV57G1kU7'"),
#  ('\\xe2\\x80\\xa6', "https://t.co/sPV57G1kU7'", '39'),
#  ("https://t.co/sPV57G1kU7'", '39', 'NaN'),
#  ('39', 'NaN', '40'),
#  ('NaN', '40', 'NaN'),
#  ('40', 'NaN', '41'),
#  ('NaN', '41', 'NaN'),
#  ('41', 'NaN', '42'),
#  ('NaN', '42', 'NaN'),
#  ('42', 'NaN', '43'),
#  ('NaN', '43', 'NaN'),
#  ('43', 'NaN', '44'),
#  ('NaN', '44', 'NaN'),
#  ...]
